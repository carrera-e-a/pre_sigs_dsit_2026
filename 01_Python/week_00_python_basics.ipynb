# %%
#Date: 6/15/2026
#Hour: 22:20
# Mein erste uben mit Jupyer Lab und sein Python Kernel.
#Variables
Name = "Klaus"
Age = 32
Objective = "Prepare for SIGS"

print(Name)
print(Age)
print(Objective)
# Out:
# Klaus
# 32
# Prepare for SIGS

# %%
print(Name + str(Age))
# Out:
# Klaus32

# %%
#Lists
Subjects = ["Python", "Pandas", "Statistics", "Lineal Algebra", "Machine Learning"]

for subject in Subjects:
    print("Ich muss studiere:", subject)
# Out:
# Ich muss studiere: Python
# Ich muss studiere: Pandas
# Ich muss studiere: Statistics
# Ich muss studiere: Lineal Algebra
# Ich muss studiere: Machine Learning

# %% [markdown]
# # Day Notes
#
# Heute ich habe konfiguriert mein studieren Umfeld und ich habe mein erstes Notizbuch gemacht.
#
# # Dingen ich habe geübt
#
# - Variables
# - Lists
# - Dictionaries (nein, noch nicht)
# - Functions (nein, noch nicht)
# - Loops
